# %% [markdown]
# ## Test Notebook

# %%
derp=rnorm(100,0,2)

# %%
hist(derp)
# Out:
# Plot with title “Histogram of derp”

# %%
plot(density(derp))
# Out:
# Plot with title “density.default(x = derp)”
